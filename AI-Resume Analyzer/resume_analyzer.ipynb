# %% [markdown]
# ## Get The text from the PDF

# %%
# %pip install pdfplumber pytesseract pdf2image
# Out:
# Requirement already satisfied: pdfplumber in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (0.10.3)
# Requirement already satisfied: pytesseract in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (0.3.13)
# Requirement already satisfied: pdf2image in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (1.17.0)
# Requirement already satisfied: pdfminer.six==20221105 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (20221105)
# Requirement already satisfied: Pillow>=9.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20221105->pdfplumber) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20221105->pdfplumber) (45.0.7)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.23)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        # Try direct text extraction
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        if text.strip():
            return text.strip()
    except Exception as e:
        print(f"Direct text extraction failed: {e}")

    # Fallback to OCR for image-based PDFs
    print("Falling back to OCR for image-based PDF.")
    try:
        images = convert_from_path(pdf_path)
        for image in images:
            page_text = pytesseract.image_to_string(image)
            text += page_text + "\n"
    except Exception as e:
        print(f"OCR failed: {e}")

    return text.strip()

# %%
pdf_path = "Resume.pdf"
resume_text = extract_text_from_pdf(pdf_path)

print("\nExtracted Text from PDF:")
print(resume_text)
# Out:
# Extracted Text from PDF:
# Ruthuja R Chavan
# ruthujachavan@gmail.com | (+91) 9480868685 https://www.linkedin.com/in/ruthuja-r-chavan-73bba6365 | Hubli,Karnataka
# |
# ABOUT
# A final year B.E. Computer Science and Engineering (AIML) student at KLS Vishwanathrao Deshpande
# Institute of technology, with a strong foundation in programming, data structures, and problem-solving.
# Passionate about technology and eager to contribute to real-world projects while continuously learning and
# growing in a collaborative environment.
# EDUCATION
# B.E, Computer Science Engineering (AI & ML),Vishwanathrao Deshpande 2023 -
# Institute GPA : 8.5(current) Present
# Haliyal
# Diploma, Government Polytechnic College
# GPA : 8.5 2020-2023
# Hubli
# PROJECTS
# Healthcare Data Analysis using Power BI
# Tools: Power BI, Excel, DAX
# Analyzed healthcare data to create interactive dashboards for monitoring patient outcomes,
# treatment effectiveness, and hospital efficiency.
# Integrated multiple datasets to track key metrics such as readmission rates and resource
# utilization.
# Personal Responsive Portfolio Website
# HTML, CSS
# Designed and developed a fully responsive personal portfolio website.
# Showcased skills, academic background, and project work in a clean, user-friendly layout.
# Implemented mobile-first design principles for optimal viewing across devices.
# TECHNICAL SKILLS
# Programming : Python
# Web Technologies : HTML/CSS
# Tools : PowerBi
# CERTIFICATIONS
# Introduction to Modern AI – Cisco Networking Academy
# Introduction to Cybersecurity – Cisco Networking Academy
# Employability Enhancement Program, Aptitude, Soft Skills & Technical Training - Aspire for Her
# by Infosys Foundation
# Microsoft Azure AI Fundamentals – Microsoft Learn
# ADDITIONAL INFORMATION
# Languages known : English, Hindi, Kannada, Marathi.

# %% [markdown]
# Set Google GenerativeAI Api Key

# %%
# %pip install google.generativeai python-dotenv
# Out:
# Requirement already satisfied: google.generativeai in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (0.3.2)
# Requirement already satisfied: python-dotenv in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: google-ai-generativelanguage==0.4.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (0.4.0)
# Requirement already satisfied: google-auth in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (2.40.3)
# Requirement already satisfied: google-api-core in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (2.26.0)
# Requirement already satisfied: typing-extensions in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (4.15.0)
# Requirement already satisfied: protobuf in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (6.32.1)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-ai-generativelanguage==0.4.0->google.generativeai) (1.26.1)
# Collecting protobuf (from google.generativeai)
#   Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google.generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google.generativeai) (2.31.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google.generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google.generativeai) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-auth->google.generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-auth->google.generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-auth->google.generativeai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth->google.generativeai) (0.6.1)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from tqdm->google.generativeai) (0.4.6)
# Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.32.1
#     Uninstalling protobuf-6.32.1:
#       Successfully uninstalled protobuf-6.32.1
# Successfully installed protobuf-4.25.8
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
response = model.generate_content("What is the capital of India?")

# %%
print(response)
# Out:
# <google.generativeai.types.generation_types.GenerateContentResponse object at 0x000001251BADFE60>

# %%
print(response.text)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# Resume Analysis

# %%
def analyze_resume(resume_text, job_description=None):
    if not resume_text:
        return {"error": "Resume text is required for analysis."}
    
    model = genai.GenerativeModel("gemini-2.5-flash")
    
    base_prompt = f"""
    You are an experienced HR with Technical Experience in the field of any one job role from Data Science, Data Analyst, DevOPS, Machine Learning Engineer, Prompt Engineer, AI Engineer, Full Stack Web Development, Big Data Engineering, Marketing Analyst, Human Resource Manager, Software Developer your task is to review the provided resume.
    Please share your professional evaluation on whether the candidate's profile aligns with the role.ALso mention Skills he already have and siggest some skills to imorve his resume , alos suggest some course he might take to improve the skills.Highlight the strengths and weaknesses.

    Resume:
    {resume_text}
    """

    if job_description:
        base_prompt += f"""
        Additionally, compare this resume to the following job description:
        
        Job Description:
        {job_description}
        
        Highlight the strengths and weaknesses of the applicant in relation to the specified job requirements.
        """

    response = model.generate_content(base_prompt)

    analysis = response.text.strip()
    return analysis

# %%
print(analyze_resume(resume_text))
# Out:
# Okay, Ruthuja's resume is in front of me. As an HR professional with technical experience, I'll review this with an eye towards a specific role.
#
# ---
#
# ### **Professional Evaluation: Data Analyst (Entry-Level)**
#
# Based on Ruthuja's profile, the most immediate and aligned role would be an **Entry-Level Data Analyst**. Her academic background in AI & ML also makes her a strong candidate for future growth into AI/ML roles, but her current projects and demonstrated skills align most directly with data analysis functions.
#
# ---
#
# ### **Alignment with Data Analyst Role:**
#
# **Strong Alignment:**
#
# *   **Project Relevance:** The "Healthcare Data Analysis using Power BI" project is a direct hit. It demonstrates practical application of data analysis tools (Power BI, Excel, DAX), the ability to integrate datasets, track key metrics, and derive insights for monitoring efficiency and outcomes. This is exactly what an entry-level data analyst does.
# *   **Tool Proficiency:** Explicit mention of Power BI, Excel (implied by DAX and project description), and DAX are core skills for a data analyst.
# *   **Academic Background:** A B.E. in Computer Science Engineering (AI & ML) provides a strong computational and analytical foundation, which is highly beneficial for understanding data concepts and potentially more complex analytical tasks.
# *   **Programming Base:** Python is a fundamental language for data analysis, and its inclusion is positive.
# *   **Proactive Learning:** Certifications in AI Fundamentals show an interest in the broader data and AI landscape, which is valuable.
#
# **Areas for Improvement (for stronger alignment):**
#
# *   **Database Skills:** The absence of SQL is a significant gap for almost any data-centric role.
# *   **Advanced Data Manipulation:** While Python is listed, there's no mention of specific libraries like Pandas or NumPy, which are crucial for data wrangling in Python.
# *   **Statistical Understanding:** While "analyzed data" is mentioned, a clearer indication of statistical knowledge would be beneficial.
#
# ---
#
# ### **Skills Ruthuja Already Possesses:**
#
# **Technical Skills:**
#
# *   **Data Visualization & Reporting:** Power BI, DAX, Excel (implied)
# *   **Programming:** Python (foundational)
# *   **Web Technologies (Basic):** HTML/CSS (useful for personal branding/portfolio)
# *   **Conceptual Understanding:** Data analysis, problem-solving, data structures (as stated in "About")
# *   **Cloud & AI Fundamentals:** Microsoft Azure AI Fundamentals, Introduction to Modern AI (Cisco)
#
# **Soft Skills & Attributes:**
#
# *   **Eagerness to Learn & Grow:** Explicitly stated and demonstrated through certifications and academic pursuits.
# *   **Collaboration:** Expressed desire to work in a collaborative environment.
# *   **Problem-Solving:** A core engineering skill, reinforced by the data analysis project.
# *   **Attention to Detail:** Implied by the analytical nature of the healthcare project.
# *   **Multilingual:** English, Hindi, Kannada, Marathi.
#
# ---
#
# ### **Strengths:**
#
# 1.  **Strong Relevant Project:** The "Healthcare Data Analysis using Power BI" project is the resume's biggest asset. It's well-described, demonstrates clear impact, and directly applies to data analysis.
# 2.  **Excellent Academic Record:** Consistent 8.5 GPA across both Diploma and B.E. shows dedication and strong comprehension.
# 3.  **AIML Specialization:** The B.E. focus on AI & ML provides a cutting-edge foundation and positions her well for future advanced analytics or machine learning roles.
# 4.  **Demonstrated Tool Proficiency:** Practical experience with Power BI, Excel, and DAX is a significant plus for an entry-level role.
# 5.  **Proactive Learning:** The certifications, especially in Azure AI and Modern AI, highlight initiative and a commitment to staying updated in technology.
# 6.  **Foundational Python:** Having Python as a programming language is crucial for modern data roles.
#
# ---
#
# ### **Weaknesses:**
#
# 1.  **Limited Core Data Skills:** The absence of SQL is a major oversight for a data role.
# 2.  **Basic Python Application:** While Python is listed, there's no mention of its application in data analysis (e.g., Pandas, NumPy).
# 3.  **Narrow Technical Stack for Data:** Only Power BI is listed as a dedicated data tool (besides Python). Modern data analysts often work with a broader set, including other visualization tools (e.g., Tableau), or more advanced data manipulation libraries.
# 4.  **Lack of Version Control:** No mention of Git/GitHub, which is standard practice for showcasing code-based projects and collaboration.
# 5.  **Limited Project Diversity (for AI/ML):** While the data analysis project is strong, for an AI/ML role, more projects demonstrating machine learning model building, deployment, or advanced AI concepts would be needed.
# 6.  **Generic "About" Section:** While enthusiastic, it could be more focused on specific career aspirations (e.g., "seeking an entry-level Data Analyst role to leverage analytical skills and contribute to data-driven decision-making").
#
# ---
#
# ### **Suggested Skills to Improve:**
#
# To enhance Ruthuja's profile for Data Analyst and future AI/ML roles:
#
# 1.  **SQL (Structured Query Language):** Absolutely essential for querying databases, which is a daily task for data analysts.
# 2.  **Advanced Python Libraries for Data:**
#     *   **Pandas:** For data manipulation and analysis.
#     *   **NumPy:** For numerical computing.
#     *   **Matplotlib/Seaborn:** For advanced data visualization in Python.
# 3.  **Git & GitHub:** For version control, collaboration, and showcasing code-based projects.
# 4.  **Statistical Analysis:** Deeper understanding of descriptive and inferential statistics, hypothesis testing.
# 5.  **Data Cleaning & ETL Concepts:** Understanding how to clean messy data and the basics of Extract, Transform, Load processes.
# 6.  **Cloud Data Services (Azure Specific):** Given her Azure AI certification, exploring Azure Data Factory, Azure Synapse Analytics, or Azure SQL Database would be beneficial.
# 7.  **Another Visualization Tool (Optional but Recommended):** Tableau is a popular alternative to Power BI and demonstrating proficiency in both can be a strong asset.
#
# ---
#
# ### **Suggested Courses to Improve Skills:**
#
# Here are some excellent resources for Ruthuja:
#
# 1.  **For SQL:**
#     *   **"SQL for Data Analysts"** on Udemy or Coursera (e.g., IBM's "Databases and SQL for Data Science with Python").
#     *   **DataCamp:** "Introduction to SQL" track.
#     *   **FreeCodeCamp:** Relational Database Curriculum (Project-based learning).
# 2.  **For Python Data Analysis (Pandas, NumPy, Matplotlib/Seaborn):**
#     *   **"Python for Data Science and Machine Learning Bootcamp"** by Jose Portilla on Udemy.
#     *   **Coursera Specialization:** "Applied Data Science with Python" from the University of Michigan.
#     *   **DataCamp:** "Python Programmer" or "Data Scientist with Python" career tracks.
# 3.  **For Git & GitHub:**
#     *   **"Introduction to Git and GitHub"** on Coursera or Udemy.
#     *   **freeCodeCamp:** "Learn Git and GitHub - Crash Course for Beginners."
# 4.  **For Statistics:**
#     *   **"Statistics for Data Science with Python"** on Coursera (IBM).
#     *   **Khan Academy:** Statistics and Probability course (excellent foundational learning).
# 5.  **For Cloud Data Services (Azure):**
#     *   **Microsoft Learn Paths:** Explore "Azure Data Fundamentals (DP-900)" and then potentially "Azure Data Engineer Associate (DP-203)" if interested in that path, or "Azure AI Engineer Associate (AI-102)" for more AI-specific deployment.
# 6.  **For Tableau:**
#     *   **"Tableau 2023 Masterclass"** or similar on Udemy.
#     *   **Coursera:** "Tableau Fundamentals" by the University of California, Davis.
#
# ---
#
# **Overall Impression:** Ruthuja has a very promising profile for an entry-level Data Analyst, with a strong foundation and an impressive project. By strategically acquiring a few more core data analysis skills, especially SQL and advanced Python for data, she can significantly strengthen her candidacy and open up more opportunities. I would definitely consider her for an interview based on her current resume, especially if our team values proactive learning and foundational AI/ML knowledge.
